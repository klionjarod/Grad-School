# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('traindata.csv')
df2 = pd.read_csv('testdata.csv')

# %%
pd.set_option("max_rows", None)

# %%
df.sort_values('Age', ascending=False)
# Out:
#       Age  Gender  Chest Pain  Blood Pr  Cholesterol  Blood Sugar  \
# 42   71.0     0.0         2.0     160.0        302.0          0.0
# 103  71.0     0.0         3.0     110.0        265.0          1.0
# 136  70.0     1.0         4.0     145.0        174.0          0.0
# 30   69.0     0.0         1.0     140.0        239.0          0.0
# 83   68.0     1.0         3.0     180.0        274.0          1.0
# 71   67.0     1.0         4.0     125.0        254.0          1.0
# 2    67.0     1.0         4.0     120.0        229.0          0.0
# 1    67.0     1.0         4.0     160.0        286.0          0.0
# 90   66.0     1.0         4.0     120.0        302.0          0.0
# 27   66.0     0.0         1.0     150.0        226.0          0.0
# 124  65.0     1.0         1.0     138.0        282.0          1.0
# 40   65.0     0.0         4.0     150.0        225.0          0.0
# 48   65.0     0.0         3.0     140.0        417.0          1.0
# ...

# %%
#Filter by men with specific criteria then women with their criteria for YES
filter1 = ((df2["Gender"]== 1) & (df2["defect"] >= 6) & (df2['Cholesterol'] >= 167)) |\
          ((df2["Gender"] == 0) & (df2["Cholesterol"] >= 290) & (df2["Chest Pain"] > 3))

#Filters for NO
filter2 = ((df2["Gender"] == 1) & (df2["Blood Pr"] <= 178) & (df2["Cholesterol"] <= 270 )& (df2["Chest Pain"] <= 3)) |\
          (df2["Gender"] == 0)
#df_test = df.copy()

# %%
#Initialize the column
#df_test['test result'] = ''
df2['test result'] = ''

#Apply filters
#df_test.loc[filter2, ['test result']] = "no"
#df_test.loc[filter1, ['test result']] = "yes"
df2.loc[filter2, ['test result']] = "no"
df2.loc[filter1, ['test result']] = "yes"

# %%
df_test[df_test["Gender"]==1].sort_values('Result', ascending=False)
# Out:
#       Age  Gender  Chest Pain  Blood Pr  Cholesterol  Blood Sugar  \
# 73   65.0     1.0         4.0     110.0        248.0          0.0
# 71   67.0     1.0         4.0     125.0        254.0          1.0
# 52   44.0     1.0         4.0     112.0        290.0          0.0
# 124  65.0     1.0         1.0     138.0        282.0          1.0
# 54   60.0     1.0         4.0     130.0        253.0          0.0
# 55   54.0     1.0         4.0     124.0        266.0          0.0
# 56   50.0     1.0         3.0     140.0        233.0          0.0
# 57   41.0     1.0         4.0     110.0        172.0          0.0
# 123  55.0     1.0         4.0     140.0        217.0          0.0
# 62   58.0     1.0         4.0     128.0        216.0          0.0
# 64   54.0     1.0         4.0     120.0        188.0          0.0
# 65   60.0     1.0         4.0     145.0        282.0          0.0
# 66   60.0     1.0         3.0     140.0        185.0          0.0
# ...

# %%
df2.sort_values('Result', ascending=False)
# Out:
#      Age  Gender  Chest Pain  Blood Pr  Cholesterol  Blood Sugar  \
# 10  43.0     1.0         4.0     132.0        247.0          1.0
# 2   60.0     0.0         4.0     158.0        305.0          0.0
# 5   66.0     1.0         2.0     160.0        246.0          0.0
# 6   54.0     1.0         2.0     192.0        283.0          0.0
# 7   69.0     1.0         3.0     140.0        254.0          0.0
# 17  59.0     1.0         1.0     160.0        273.0          0.0
# 9   51.0     1.0         4.0     140.0        298.0          0.0
# 11  62.0     0.0         4.0     138.0        294.0          1.0
# 13  67.0     1.0         4.0     100.0        299.0          0.0
# 14  69.0     1.0         1.0     160.0        234.0          1.0
# 19  64.0     0.0         4.0     180.0        325.0          0.0
# 18  50.0     0.0         4.0     110.0        254.0          0.0
# 16  50.0     0.0         2.0     120.0        244.0          0.0
# ...
